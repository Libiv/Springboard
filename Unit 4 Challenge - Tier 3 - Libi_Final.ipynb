# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

#print(pd.__version__)

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
#properties.head()

# %%
#properties.info

# %%
#properties.isna()any()

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
del properties["Unnamed: 33"]
del properties["Unnamed: 46"]
del properties["Unnamed: 36"]
properties.isna().sum()
# Out:
# City of London          0
# Barking & Dagenham      0
# Barnet                  0
# Bexley                  0
# Brent                   0
# Bromley                 0
# Camden                  0
# Croydon                 0
# Ealing                  0
# Enfield                 0
# Greenwich               0
# Hackney                 0
# Hammersmith & Fulham    0
# Haringey                0
# Harrow                  0
# Havering                0
# Hillingdon              0
# Hounslow                0
# Islington               0
# Kensington & Chelsea    0
# Kingston upon Thames    0
# Lambeth                 0
# Lewisham                0
# Merton                  0
# Newham                  0
# Redbridge               0
# Richmond upon Thames    0
# Southwark               0
# Sutton                  0
# Tower Hamlets           0
# Waltham Forest          0
# Wandsworth              0
# Westminster             0
# Inner London            0
# Outer London            0
# ...

# %%
properties= properties.transpose()
#properties.isna().sum()
properties.head()
# Out:
#                           NaT 1995-01-01 1995-02-01 1995-03-01 1995-04-01  \
# City of London      E09000001      91449    82202.8    79120.7    77101.2
# Barking & Dagenham  E09000002    50460.2    51085.8      51269    53133.5
# Barnet              E09000003    93284.5    93190.2    92247.5    90762.9
# Bexley              E09000004    64958.1    64787.9    64367.5    64277.7
# Brent               E09000005    71306.6    72022.3    72015.8    72965.6
#
#                    1995-05-01 1995-06-01 1995-07-01 1995-08-01 1995-09-01  \
# City of London        84409.1    94900.5     110128     112329     104473
# Barking & Dagenham    53042.2    53700.3    52113.1    52232.2    51471.6
# Barnet                  90258    90107.2    91441.2    92361.3    93273.1
# Bexley                63997.1    64252.3    63722.7    64432.6    64509.5
# Brent                   73704    74310.5      74127      73547    73789.5
#
# ...

# %%
properties = properties.reset_index()

# %%
properties.index
# Out:
# RangeIndex(start=0, stop=45, step=1)

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties= properties.rename(columns= { 'index':'London_Borough',pd.NaT:'ID'})

# %%
properties.head()
# Out:
#        London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0      City of London  E09000001               91449             82202.8
# 1  Barking & Dagenham  E09000002             50460.2             51085.8
# 2              Barnet  E09000003             93284.5             93190.2
# 3              Bexley  E09000004             64958.1             64787.9
# 4               Brent  E09000005             71306.6             72022.3
#
#   1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0             79120.7             77101.2             84409.1
# 1               51269             53133.5             53042.2
# 2             92247.5             90762.9               90258
# 3             64367.5             64277.7             63997.1
# 4             72015.8             72965.6               73704
#
#   1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  \
# 0             94900.5              110128              112329
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
clean_properties = pd.melt(properties, id_vars= ['London_Borough', 'ID'])

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties.shape
# Out:
# (45, 318)

# %%
clean_properties
# Out:
#              London_Borough         ID   variable        value
# 0            City of London  E09000001 1995-01-01        91449
# 1        Barking & Dagenham  E09000002 1995-01-01      50460.2
# 2                    Barnet  E09000003 1995-01-01      93284.5
# 3                    Bexley  E09000004 1995-01-01      64958.1
# 4                     Brent  E09000005 1995-01-01      71306.6
# 5                   Bromley  E09000006 1995-01-01      81671.5
# 6                    Camden  E09000007 1995-01-01       120933
# 7                   Croydon  E09000008 1995-01-01      69158.2
# 8                    Ealing  E09000009 1995-01-01      79885.9
# 9                   Enfield  E09000010 1995-01-01      72514.7
# 10                Greenwich  E09000011 1995-01-01      62300.1
# 11                  Hackney  E09000012 1995-01-01      61296.5
# 12     Hammersmith & Fulham  E09000013 1995-01-01       124903
# 13                 Haringey  E09000014 1995-01-01      76287.6
# ...

# %%
clean_properties = clean_properties.rename(columns = {'variable': 'Month','value': "Avg_price"})

# %%
clean_properties.head()
# Out:
#        London_Borough         ID      Month Avg_price
# 0      City of London  E09000001 1995-01-01     91449
# 1  Barking & Dagenham  E09000002 1995-01-01   50460.2
# 2              Barnet  E09000003 1995-01-01   93284.5
# 3              Bexley  E09000004 1995-01-01   64958.1
# 4               Brent  E09000005 1995-01-01   71306.6

# %%
clean_properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Avg_price                 object
# dtype: object

# %%
clean_properties['Avg_price']=pd.to_numeric(clean_properties['Avg_price'])

# %%
clean_properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Avg_price                float64
# dtype: object

# %%
#clean_properties.isna().sum()

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
#clean_properties.count()

# %%
#clean_properties["London_Borough"].unique()

# %%
#clean_properties[clean_properties['ID'].isna()]

# %%
non_Boroughs_list = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

# %%
#Filter rows values for non_Boroughs_df that are in the nonBoroughs list.
non_Boroughs_df = clean_properties[clean_properties.London_Borough.isin(non_Boroughs_list)]
#non_Boroughs_df.London_Borough.unique()

# %%
#Filter rows values for Boroughs_properties that are NOT in the nonBoroughs list.
Boroughs_properties = clean_properties[~clean_properties.London_Borough.isin(non_Boroughs_list)]
#Boroughs_properties.London_Borough.unique()

# %%
df = Boroughs_properties
df.head()
# Out:
#        London_Borough         ID      Month    Avg_price
# 0      City of London  E09000001 1995-01-01  91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.22660
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698

# %%
df.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Avg_price                float64
# dtype: object

# %%
# We are interested in data over the period of TWO DECADES back: 2000-2020 
## to simplify: I didn't refer to data from 2021,that has only partly data for 2021
temp_df = df.set_index("Month").sort_index()
df_temp = temp_df.loc["2000-01-01":"2020-01-01"]
df_temp
# Out:
#                   London_Borough         ID     Avg_price
# Month
# 2000-01-01        City of London  E09000001  1.737385e+05
# 2000-01-01    Barking & Dagenham  E09000002  7.107919e+04
# 2000-01-01                Barnet  E09000003  1.536761e+05
# 2000-01-01                Bexley  E09000004  9.497847e+04
# 2000-01-01                 Brent  E09000005  1.267848e+05
# 2000-01-01               Bromley  E09000006  1.339970e+05
# 2000-01-01                Camden  E09000007  2.176996e+05
# 2000-01-01               Croydon  E09000008  1.091188e+05
# 2000-01-01                Ealing  E09000009  1.443523e+05
# 2000-01-01               Enfield  E09000010  1.116886e+05
# 2000-01-01             Greenwich  E09000011  1.024106e+05
# 2000-01-01               Hackney  E09000012  1.211352e+05
# 2000-01-01  Hammersmith & Fulham  E09000013  2.294646e+05
# 2000-01-01              Haringey  E09000014  1.339528e+05
# 2000-01-01                Harrow  E09000015  1.411150e+05
# ...

# %%
""" 
TO Dipanjan: 

Question 1 - what happend to column Avg_price?
why the format of the float has changed, to 1 dot aftaer the first number?,
and whats the best way to deal with it?
"""
# Out:
# ' \nTO Dipanjan: \n\nQuestion 1 - what happend to column Avg_price?\nwhy the format of the float has changed, to 1 dot aftaer the first number?,\nand whats the best way to deal with it?\n'

# %%
df_temp = df_temp.reset_index()

# %%
# return to original df column order
df = df_temp[["London_Borough","ID","Month","Avg_price"]]
df
# Out:
#             London_Borough         ID      Month     Avg_price
# 0           City of London  E09000001 2000-01-01  1.737385e+05
# 1       Barking & Dagenham  E09000002 2000-01-01  7.107919e+04
# 2                   Barnet  E09000003 2000-01-01  1.536761e+05
# 3                   Bexley  E09000004 2000-01-01  9.497847e+04
# 4                    Brent  E09000005 2000-01-01  1.267848e+05
# 5                  Bromley  E09000006 2000-01-01  1.339970e+05
# 6                   Camden  E09000007 2000-01-01  2.176996e+05
# 7                  Croydon  E09000008 2000-01-01  1.091188e+05
# 8                   Ealing  E09000009 2000-01-01  1.443523e+05
# 9                  Enfield  E09000010 2000-01-01  1.116886e+05
# 10               Greenwich  E09000011 2000-01-01  1.024106e+05
# 11                 Hackney  E09000012 2000-01-01  1.211352e+05
# 12    Hammersmith & Fulham  E09000013 2000-01-01  2.294646e+05
# 13                Haringey  E09000014 2000-01-01  1.339528e+05
# ...

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
df[df["London_Borough"]=='Brent'].plot(x="Month",y="Avg_price", kind="line")
plt.title("Bret Average price over 2000-2020")
plt.show()

# %%
"""
TO Dipanjan: 
Question 2 - how to add ylable to the plot? 
plt.ylable("average price") - didn"t work
plt.set_ylable("average price")  - didn't work
"""
# Out:
# '\nTO Dipanjan: \nQuestion 2 - how to add ylable to the plot? \nplt.ylable("average price") - didn"t work\nplt.set_ylable("average price")  - didn\'t work\n'

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
df["Year"] = df["Month"].apply(lambda m : m.year) 
df
# Out:
# C:\Users\libiv\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#             London_Borough         ID      Month     Avg_price  Year
# 0           City of London  E09000001 2000-01-01  1.737385e+05  2000
# 1       Barking & Dagenham  E09000002 2000-01-01  7.107919e+04  2000
# 2                   Barnet  E09000003 2000-01-01  1.536761e+05  2000
# 3                   Bexley  E09000004 2000-01-01  9.497847e+04  2000
# 4                    Brent  E09000005 2000-01-01  1.267848e+05  2000
# 5                  Bromley  E09000006 2000-01-01  1.339970e+05  2000
# 6                   Camden  E09000007 2000-01-01  2.176996e+05  2000
# ...

# %%
"""
to Dipanjan: for previouse line of code I'm somtime recieving the following warning messege:

C:\Users\libiv\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning: 
A value is trying to be set on a copy of a slice from a DataFrame.
Try using .loc[row_indexer,col_indexer] = value instead

See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
  Entry point for launching an IPython kernel.
Should I ignore it? or is there's a better way to deal with it?
"""
# Out:
#   File "<ipython-input-38-628d7fccf778>", line 11
#     """
#       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 97-98: truncated \UXXXXXXXX escape

# %%
borough_yearly_mean = df.groupby(["London_Borough","Year"])["Avg_price"].mean()
borough_yearly_mean
# Out:
# London_Borough      Year
# Barking & Dagenham  2000    7.754951e+04
#                     2001    8.866406e+04
#                     2002    1.122219e+05
#                     2003    1.424989e+05
#                     2004    1.581760e+05
#                     2005    1.633608e+05
#                     2006    1.678533e+05
#                     2007    1.849098e+05
#                     2008    1.873569e+05
#                     2009    1.564469e+05
#                     2010    1.665607e+05
#                     2011    1.634651e+05
#                     2012    1.658639e+05
#                     2013    1.737336e+05
#                     2014    2.011722e+05
#                     2015    2.334601e+05
#                     2016    2.739196e+05
#                     2017    2.877347e+05
#                     2018    2.951967e+05
#                     2019    2.983379e+05
#                     2020    3.030554e+05
# Barnet              2000    1.679526e+05
# ...

# %%
"""הדרך הכי טובה היא ליצור פונקציה שמקבלת שם של שכונה מתוך רשימת 32 השכונות:
מייצרת פונקציה /גרף לשינוי מחיר ממוצע על פני זמן.
עושה נגזרת לגרף/פונקציה 
ובודקת מה הנגזרת הכי גדולה (חיובית) 
משמע שינוי/עלייה הכי גדולה"""
# Out:
# 'הדרך הכי טובה היא ליצור פונקציה שמקבלת שם של שכונה מתוך רשימת 32 השכונות:\nמייצרת פונקציה /גרף לשינוי מחיר ממוצע על פני זמן.\nעושה נגזרת לגרף/פונקציה \nובודקת מה הנגזרת הכי גדולה (חיובית) \nמשמע שינוי/עלייה הכי גדולה'

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
dfg = borough_yearly_mean.reset_index()
#dfg

# %%
# creating Boroughs names list: list_of_boroughs (contains ''City of London')
dfg_temp = dfg.set_index("London_Borough")
list_of_boroughs = list(dfg_temp.index.unique())
#list_of_boroughs

# %%
"""
def create_price_ratio():
    #price_ratio = list()
    for borough in list_of_boroughs:      #runs through all boroughs
        price_ratio = dfg[(dfg['London_Borough']==borough)&(dfg['Year'] == '2000')]/dfg[(dfg['London_Borough']==borough)&(dfg['Year'] == '2020')]
        
"""

# %%
def create_price_ratio(f_df, from_year, to_year):
    ratios = list()
    for borough in list_of_boroughs:
        avg_price_from_year = f_df[(f_df['London_Borough']==borough) & (f_df['Year'] == from_year)].Avg_price
        avg_price_up_to_year = f_df[(f_df['London_Borough']==borough) & (f_df['Year'] == to_year)].Avg_price
        ratios.append(float(avg_price_from_year)/float(avg_price_up_to_year))
    #print(type(ratios))
    borough_ratios = list(zip(list_of_boroughs,ratios))
    return borough_ratios

#create_price_ratio(dfg, 2000, 2020)
#type(create_price_ratio(dfg))

# %% [markdown]
# Answer to:
# ### Which borough had the greatest increase in housing prices, on average, over the last two decades

# %%
max(create_price_ratio(dfg,2000,2020), key=lambda item: item[1])
# Out:
# ('Richmond upon Thames', 0.3459008614649744)

# %% [markdown]
# ### Which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?

# %% [markdown]
# Presenting:
# #### All boroughs in descending order:

# %%
# sorted by greatest increase in descending order
Sorted_by_AvgPriceRatio = sorted(create_price_ratio(dfg,2000,2020), key=lambda x: x[1], reverse=True)

# present each borough with it's ratio in seperate line 
#for elem in Sorted_by_AvgPriceRatio:
#        print(elem)

# %%
"""
# using *sort method* - hasnt worked

t= create_price_ratio(dfg,2000,2020)
n =t.sort(key=lambda x: x[1]) 
print(n)

# %%
"""
#Option to sort with 'operator.itemgetter' - hasnt worked either

import operator
t = create_price_ratio(dfg,2000,2020)
a= t.sort(key=operator.itemgetter(1))
print(a)

# %%
# present each borough with it's ratio in DataFrame look: 
bor_list=list()
rat_list=list()

#separating boroughs and ratios in seperate lists
for item in Sorted_by_AvgPriceRatio:
    bor,rat = item
    bor_list.append(bor)
    rat_list.append(rat)

#create dictionary with borough and ratios as keys
bor_dict = {'London_Borough':bor_list, 'Price_Ratio':rat_list }
#import dictionary to a DataFrame for better presentation
df_ratios = pd.DataFrame(bor_dict)
df_ratios
# Out:
#           London_Borough  Price_Ratio
# 0   Richmond upon Thames     0.345901
# 1   Hammersmith & Fulham     0.342336
# 2                 Harrow     0.340888
# 3                Bromley     0.340460
# 4                 Sutton     0.339098
# 5   Kingston upon Thames     0.332649
# 6               Hounslow     0.332026
# 7                  Brent     0.329286
# 8                 Ealing     0.327991
# 9             Hillingdon     0.324500
# 10                Barnet     0.322098
# 11               Croydon     0.318547
# 12               Enfield     0.312826
# 13                Bexley     0.306392
# 14         Tower Hamlets     0.305314
# 15            Wandsworth     0.304483
# 16                Merton     0.303855
# 17              Havering     0.303263
# 18  Kensington & Chelsea     0.301328
# 19                Camden     0.298239
# 20             Redbridge     0.296350
# 21             Islington     0.289287
# 22               Lambeth     0.283280
# 23             Southwark     0.283061
# ...

# %% [markdown]
# Presenting:
# #### TOP 10 boroughs in descending order:

# %%
## SUGGESTION FROM TIER 1- 
# Select the top 10 boroughs:
top10 = df_ratios.head(10)
top10
# Out:
#          London_Borough  Price_Ratio
# 0  Richmond upon Thames     0.345901
# 1  Hammersmith & Fulham     0.342336
# 2                Harrow     0.340888
# 3               Bromley     0.340460
# 4                Sutton     0.339098
# 5  Kingston upon Thames     0.332649
# 6              Hounslow     0.332026
# 7                 Brent     0.329286
# 8                Ealing     0.327991
# 9            Hillingdon     0.324500

# %%
df
# Out:
#             London_Borough         ID      Month     Avg_price  Year
# 0           City of London  E09000001 2000-01-01  1.737385e+05  2000
# 1       Barking & Dagenham  E09000002 2000-01-01  7.107919e+04  2000
# 2                   Barnet  E09000003 2000-01-01  1.536761e+05  2000
# 3                   Bexley  E09000004 2000-01-01  9.497847e+04  2000
# 4                    Brent  E09000005 2000-01-01  1.267848e+05  2000
# 5                  Bromley  E09000006 2000-01-01  1.339970e+05  2000
# 6                   Camden  E09000007 2000-01-01  2.176996e+05  2000
# 7                  Croydon  E09000008 2000-01-01  1.091188e+05  2000
# 8                   Ealing  E09000009 2000-01-01  1.443523e+05  2000
# 9                  Enfield  E09000010 2000-01-01  1.116886e+05  2000
# 10               Greenwich  E09000011 2000-01-01  1.024106e+05  2000
# 11                 Hackney  E09000012 2000-01-01  1.211352e+05  2000
# 12    Hammersmith & Fulham  E09000013 2000-01-01  2.294646e+05  2000
# ...

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %%
### what's the best way to check if the greatest increase in properties price was on properties that their initial price was low/High (on evarage) in the first place (in 2000).

# %%
## In the Data scorce excel file there's also data about Sales volume by borough and month-year. 
# I could check what was the influence of the price increase on the properties sales volume.
